# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw_data.csv', sep = '#')
df.head(5)

# %%
df = df[df.Genre.str.contains("500") == False]
df = df[df.Genre.str.contains("Sorry") == False]
df

# %%
df['Year']= [i[0] for i in df['Date'].str.split('-',2)]


df
# Out:
#         Position                               Track Name            Artist  \
# 0              1                                  Starboy        The Weeknd
# 1              2                                   Closer  The Chainsmokers
# 2              3                          Let Me Love You          DJ Snake
# 3              4  Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit
# 4              5                                One Dance             Drake
# ...          ...                                      ...               ...
# 321195       196             Best Friend (feat. Doja Cat)          Saweetie
# 321196       197                  Wonderwall - Remastered             Oasis
# 321197       198                         MI FAI IMPAZZIRE            BLANCO
# 321198       199                                Adore You      Harry Styles
# 321199       200                               Follow You   Imagine Dragons
#
#         Streams        Date  \
# ...

# %%
df['Month']= [i[1] for i in df['Date'].str.split('-',2)]

# %%
df['Day']= [i[2] for i in df['Date'].str.split('-',2)]
df
# Out:
#         Position                               Track Name            Artist  \
# 0              1                                  Starboy        The Weeknd
# 1              2                                   Closer  The Chainsmokers
# 2              3                          Let Me Love You          DJ Snake
# 3              4  Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit
# 4              5                                One Dance             Drake
# ...          ...                                      ...               ...
# 321195       196             Best Friend (feat. Doja Cat)          Saweetie
# 321196       197                  Wonderwall - Remastered             Oasis
# 321197       198                         MI FAI IMPAZZIRE            BLANCO
# 321198       199                                Adore You      Harry Styles
# 321199       200                               Follow You   Imagine Dragons
#
#         Streams        Date  \
# ...

# %%
limpa = lambda x: x[2:-1].split("\'",1)[0]


df.Genre = df.Genre.apply(lambda row: limpa(str(row)))

# %%
df['Genre']
# Out:
# 0         canadian pop
# 1                  pop
# 2                  pop
# 3                  pop
# 4          toronto rap
#               ...
# 321195      trap queen
# 321196      madchester
# 321197     italian pop
# 321198             pop
# 321199     modern rock
# Name: Genre, Length: 320622, dtype: object

# %%
df = df.drop('Date', axis='columns')

# %%
df = df.drop('Position', axis='columns')

# %%
df.to_csv('../data/data_TRATADO.csv')
df
# Out:
#                                      Track Name            Artist  Streams  \
# 0                                       Starboy        The Weeknd  3135625
# 1                                        Closer  The Chainsmokers  3015525
# 2                               Let Me Love You          DJ Snake  2545384
# 3       Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit  2356604
# 4                                     One Dance             Drake  2259887
# ...                                         ...               ...      ...
# 321195             Best Friend (feat. Doja Cat)          Saweetie   790257
# 321196                  Wonderwall - Remastered             Oasis   789099
# 321197                         MI FAI IMPAZZIRE            BLANCO   788966
# 321198                                Adore You      Harry Styles   788033
# 321199                               Follow You   Imagine Dragons   785417
#
#                Genre  Year Month Day
# ...
